# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
import statsmodels.api as sm
from statsmodels.formula.api import ols
import datetime

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv("location_coordinate.csv")

fig = px.scatter_geo(df,lat='lat',lon='long', hover_name="id")
fig.update_layout(title = 'France', title_x=0.5)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/54/ygl2prm92g7c7p73tl2p1y5w0000gn/T/ipykernel_16765/4284720869.py in <module>
#       2 import pandas as pd
#       3
# ----> 4 df = pd.read_csv("location_coordinate.csv")
#       5
#       6 fig = px.scatter_geo(df,lat='lat',lon='long', hover_name="id")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
from geopy.geocoders import Nominatim

# %%
#postal code to GPS 
geolocator = Nominatim(user_agent="my-app")

def zip_to_lat(zip):

    location = geolocator.geocode({"postalcode": "38160", "country": "France"})
    lat = location.latitude
    

    return(lat)

def zip_to_long(zip):

# %%
lat
# Out:
# 45.15548858373983

# %%
df_A=pd.read_csv("/Users/corentinpla/Documents/C-2-Statap/transactions_A.csv")
df_B=pd.read_csv("/Users/corentinpla/Documents/C-2-Statap/transactions_B.csv")

# %%
df_concat=pd.concat([df_A,df_B])

# %%
df_concat.head()
# Out:
#    tx_id  sender_account_id  receiver_account_id  tx_amount   timestamp  \
# 0   3109             6822.0                  NaN     229.97  2018-03-03
# 1   1829                NaN               9011.0     117.83  2018-03-03
# 2   1830                NaN               7140.0     117.83  2018-03-03
# 3   1831                NaN               1822.0     526.02  2018-03-03
# 4   1832             5390.0                  NaN      35.79  2018-03-03
#
#   tx_type sender_bank_id sender_first_name sender_last_name  \
# 0    WIRE              A             Marie              Lee
# 1    WIRE              B              Kurt          Brignac
# 2    WIRE              B              Kurt          Brignac
# 3    WIRE              C            Shelly           Jethva
# 4    WIRE              A              Judy            James
#
#   sender_country_code sender_birth_date  sender_zip_code receiver_bank_id  \
# 0                  FR        1937-08-23            27800                C
# ...

# %%
df_is_alert=df_concat[df_concat["is_alert_pooled"]==True]

# %%
df_is_alert.groupby("receiver_country_code").count()
# Out:
#                        tx_id  sender_account_id  receiver_account_id  \
# receiver_country_code
# AT                         1                  1                    0
# BR                         1                  1                    0
# CA                         1                  1                    0
# CD                         1                  1                    0
# CN                         7                  7                    0
# CO                         2                  2                    0
# EG                         5                  5                    0
# ET                         1                  1                    0
# FR                      1587                941                  977
# GB                         1                  1                    0
# ID                         3                  3                    0
# IN                         8                  8                    0
# ...

# %%
#Analyse spatiale
